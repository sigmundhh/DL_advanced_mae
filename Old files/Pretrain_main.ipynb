# %%
import sys
# check whether run in Colab
if 'google.colab' in sys.modules:
    print('Running in Colab.')
    # !pip3 install timm==0.4.5  # 0.3.2 does not work in Colab
    # !git clone https://github.com/facebookresearch/mae.git
    sys.path.append('./mae')
else:
    sys.path.append('..')
# Out:
# Running in Colab.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 287 kB 18.3 MB/s
# ...
# Cloning into 'mae'...
# remote: Enumerating objects: 39, done.
# remote: Total 39 (delta 0), reused 0 (delta 0), pack-reused 39
# Unpacking objects: 100% (39/39), done.

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e3a4a44a-6563-4829-b13b-f6e35f85f303" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3a4a44a-6563-4829-b13b-f6e35f85f303">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download ifigotin/imagenetmini-1000
# Out:
# ...
# 100% 3.92G/3.92G [01:51<00:00, 40.9MB/s]
# 100% 3.92G/3.92G [01:51<00:00, 37.9MB/s]

# %%
# !pwd
# Out:
# /content

# %%
print("Uncompressing...")
# !unzip ./imagenetmini-1000.zip
print("Data ready!")
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: imagenet-mini/train/n07875152/n07875152_2763.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_3015.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_3378.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_3497.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_3745.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_4157.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_461.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_4704.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_4789.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_4848.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_4940.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_546.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_5607.JPEG
#   inflating: imagenet-mini/train/n07875152/n07875152_5711.JPEG
# ...

# %%
#!pip install submitit
# !pip install torch==1.7.0
# !pip install torchvision==0.8.1
# !pip install timm==0.3.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 776.7 MB 4.2 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.7.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.7.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.7.0 which is incompatible.
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 12.7 MB 15.4 MB/s
# ...

# %%
import sys
import os
import requests

import torch
import numpy as np

import matplotlib.pyplot as plt
from PIL import Image

# %%
# !python mae/main_pretrain.py  --model our_mae --batch_size 32 --norm_pix_loss --mask_ratio 0.75 --epochs 2 --warmup_epochs 40 --blr 1.5e-4 --weight_decay 0.05 --data_path imagenet-mini
# Out:
# Not using distributed mode
# [10:23:02.119554] job dir: /content/mae
# [10:23:02.119631] Namespace(accum_iter=1,
# batch_size=32,
# blr=0.00015,
# data_path='imagenet-mini',
# device='cuda',
# dist_on_itp=False,
# dist_url='env://',
# distributed=False,
# epochs=2,
# input_size=224,
# local_rank=-1,
# log_dir='./output_dir',
# lr=None,
# mask_ratio=0.75,
# min_lr=0.0,
# model='our_mae',
# norm_pix_loss=True,
# num_workers=10,
# output_dir='./output_dir',
# pin_mem=True,
# resume='',
# seed=0,
# start_epoch=0,
# warmup_epochs=40,
# weight_decay=0.05,
# world_size=1)
# [10:23:02.295158] Dataset ImageFolder
#     Number of datapoints: 34745
#     Root location: imagenet-mini/train
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(224, 224), scale=(0.2, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BICUBIC)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
# ...
